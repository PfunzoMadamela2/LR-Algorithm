# %%
model=LinearRegression()
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=42)   
# Fit the model
model.fit(X_train, y_train) 
# Make predictions
y_pred = model.predict(X_test)      
# Evaluate the model
r2_Train = model.score(X_train, y_train)  # R-squared for training set
print(f'R-squared for training set: {r2_Train}')  # Display the R-squared value for training set
# Calculate Mean Squared Error and R-squared for the test set   
mse_train = mean_squared_error(y_train, model.predict(X_train))
print(f'Mean Squared Error for training set: {mse_train}')  # Display the Mean Squared Error for training set
mse_test = mean_squared_error(y_test, y_pred)    
r2_test = r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mse_test}') 
print(f'R-squared: {r2_test}')  # Display the R-squared value
# Out:
# R-squared for training set: 0.024206149301293833
# Mean Squared Error for training set: 599.0589085748337
# Mean Squared Error: 505.2473626620837
# R-squared: 0.02595415659000755

# %%
# Remove outliers based on Z-score
z_scores = np.abs(stats.zscore(df.select_dtypes(include=[np.number])))
df_clean = df[(z_scores < 3).all(axis=1)]

# %%
  # Checking for null values in the dataset
df.isnull().count()
# Out:
# title               2598
# description         2598
# level               2598
# goal                2598
# equipment           2598
# program_length      2598
# time_per_workout    2598
# total_exercises     2598
# created             2598
# last_edit           2598
# dtype: int64

# %%
df.info()  # Displaying the information about the dataset
df.describe(include='all')  # Displaying the summary statistics of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2598 entries, 0 to 2597
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             2598 non-null   object
#  1   description       2594 non-null   object
#  2   level             2598 non-null   object
#  3   goal              2598 non-null   object
#  4   equipment         2597 non-null   object
#  5   program_length    2597 non-null   float64
#  6   time_per_workout  2598 non-null   float64
#  7   total_exercises   2598 non-null   int64
#  8   created           2597 non-null   object
#  9   last_edit         2596 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 203.1+ KB
#        title  description             level              goal equipment  \
# count   2598         2594              2598              2598      2597
# unique  2598         2494                44               179         4
# ...

# %%
# declaring the variables
X = df[['program_length','total_exercises']]
y = df['time_per_workout']

# %%
#Loading the data  and declaring in to df
df =pd.read_csv('fitness_and_workout_dataset.csv')
df
# Out:
#                                                   title  \
# 0     (MASS MONSTER) High Intensity 4 Day Upper Lowe...
# 1                            (NOT MY PROGRAM)SHJ Jotaro
# 2     1 PowerLift Per Day Powerbuilding 5 Day Bro Split
# 3                         10 Week Mass Building Program
# 4                                10 week deadlift focus
# ...                                                 ...
# 2593                                                  🎧
# 2594                                   👾Reza's Routine👾
# 2595    🔥 "Upper Body Dominance: 3-Day Growth System" 🔥
# 2596                                               🙈🙉🙊🐵
# 2597                                                🥷🥷🥷
#
#                                             description  \
# 0     Build tones of muscular with this high intensi...
# 1                               Build strength and size
# 2     Based off of Andy Baker's KCS (Kingwood Streng...
# 3     This workout is designed to increase your musc...
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
